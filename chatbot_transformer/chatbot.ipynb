# %%
from transformers import BlenderbotTokenizer, BlenderbotForConditionalGeneration

# %%
import torch

# %%
model_name = "facebook/blenderbot-400M-distill"

# Load model and tokenizer
tokenizer = BlenderbotTokenizer.from_pretrained(model_name)
model = BlenderbotForConditionalGeneration.from_pretrained(model_name)
# Out:
# c:\Users\hasan\Rafi_SAA\practice_project_1\open_source_HF_models\hf_env\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\hasan\.cache\huggingface\hub\models--facebook--blenderbot-400M-distill. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`

# %% [markdown]
# Single turn input

# %%
inputs = tokenizer("Hello, how are you?", return_tensors="pt")
reply_ids = model.generate(**inputs)
reply = tokenizer.decode(reply_ids[0], skip_special_tokens=True)
print(reply)
# Out:
#  I'm doing well, thank you. How are you this fine evening? Do you have any plans?
# Error while downloading from https://huggingface.co/facebook/blenderbot-400M-distill/resolve/refs%2Fpr%2F7/model.safetensors: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
# Trying to resume download...
# '(MaxRetryError("HTTPSConnectionPool(host='huggingface.co', port=443): Max retries exceeded with url: /facebook/blenderbot-400M-distill/resolve/refs%2Fpr%2F7/model.safetensors (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002160CD99B50>, 'Connection to huggingface.co timed out. (connect timeout=10)'))"), '(Request ID: 2a5021f6-3027-468d-b7fa-6ddf1a616158)')' thrown while requesting GET https://huggingface.co/facebook/blenderbot-400M-distill/resolve/refs%2Fpr%2F7/model.safetensors
# Retrying in 1s [Retry 1/5].

# %% [markdown]
# Multi turn converstation

# %%
conversation_history = []

def chat(message):
    global conversation_history
    conversation_history.append(message)
    input_text = " ".join(conversation_history)
    inputs = tokenizer(input_text, return_tensors="pt")
    reply_ids = model.generate(**inputs)
    reply = tokenizer.decode(reply_ids[0], skip_special_tokens=True)
    conversation_history.append(reply)
    return reply

# print(chat("Hello, how are you?"))
# print(chat("What can you do?"))
input = input("you :")
chat(input)
# Out:
# Failed to interrupt the Kernel.
#
# Unable to start Kernel 'hf_env (Python 3.11.9)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from transformers import BlenderbotTokenizer, BlenderbotForConditionalGeneration

model_name = "facebook/blenderbot-400M-distill"
tokenizer = BlenderbotTokenizer.from_pretrained(model_name)
model = BlenderbotForConditionalGeneration.from_pretrained(model_name)

conversation_history = []

def chat(message):
    global conversation_history
    conversation_history.append(message)

    # prepare structured input
    input_text = ""
    for i, msg in enumerate(conversation_history):
        if i % 2 == 0:
            input_text += f"User: {msg} "
        else:
            input_text += f"Bot: {msg} "

    inputs = tokenizer(input_text, return_tensors="pt")
    reply_ids = model.generate(**inputs, max_new_tokens=50)
    reply = tokenizer.decode(reply_ids[0], skip_special_tokens=True)
    
    conversation_history.append(reply)
    return reply

# Example usage
while True:
    user_input = input("You: ")
    bot_reply = chat(user_input)
    print("Bot:", bot_reply)
